# %% [markdown]
# Determine the period (in seconds) and the frequency in (in both Hertz and radians per second) for the following:
#
# - $\cos(7t-0.5)$
# - $\cos(12\pi t - \pi/4)$
#
# Express the following as sums of complex exponentials
# - $4\cos(5\pi t - \pi/5)$
# - $3\cos(2\pi t + \pi/7)$
#
# Express the following as cosines
#
# - $(1-2j)e^{j3t} + (1+2j)e^{-j3t}$
# - $4e^{-j5\pi t} + 4e^{j5\pi t}$
#
# Determine (or estimate) the function equation:
#
# ![fig6.png](attachment:06187e98-98d2-4c99-bab1-965b7b66ffa1.png)
